# %% [markdown]
# # Problem 8
#
# The four adjacent digits in the 1000-digit number that have the greatest product are 9 × 9 × 8 × 9 = 5832.
#
# 73167176531330624919225119674426574742355349194934
# 96983520312774506326239578318016984801869478851843
# 85861560789112949495459501737958331952853208805511
# 12540698747158523863050715693290963295227443043557
# 66896648950445244523161731856403098711121722383113
# 62229893423380308135336276614282806444486645238749
# 30358907296290491560440772390713810515859307960866
# 70172427121883998797908792274921901699720888093776
# 65727333001053367881220235421809751254540594752243
# 52584907711670556013604839586446706324415722155397
# 53697817977846174064955149290862569321978468622482
# 83972241375657056057490261407972968652414535100474
# 82166370484403199890008895243450658541227588666881
# 16427171479924442928230863465674813919123162824586
# 17866458359124566529476545682848912883142607690042
# 24219022671055626321111109370544217506941658960408
# 07198403850962455444362981230987879927244284909188
# 84580156166097919133875499200524063689912560717606
# 05886116467109405077541002256983155200055935729725
# 71636269561882670428252483600823257530420752963450
#
# Find the thirteen adjacent digits in the 1000-digit number that have the greatest product. What is the value of this product?

# %%
thoudignum="..."

# %%
thoudignum[0:13]
# Out:
# '7316717653133'

# %%
numberofwindows=1000-13

# %%
thoudignum[987:(987+13)]
# Out:
# '0420752963450'

# %%
for i in range(0,987+1):
    print(thoudignum[i:(i+13)])
# Out:
# 7316717653133
# 3167176531330
# 1671765313306
# 6717653133062
# 7176531330624
# 1765313306249
# 7653133062491
# 6531330624919
# 5313306249192
# 3133062491922
# 1330624919225
# 3306249192251
# 3062491922511
# 0624919225119
# 6249192251196
# 2491922511967
# 4919225119674
# 9192251196744
# 1922511967442
# 9225119674426
# 2251196744265
# 2511967442657
# 5119674426574
# 1196744265747
# 1967442657474
# 9674426574742
# 6744265747423
# 7442657474235
# 4426574742355
# 4265747423553
# 2657474235534
# 6574742355349
# 5747423553491
# 7474235534919
# 4742355349194
# 7423553491949
# 4235534919493
# 2355349194934
# 3553491949349
# 5534919493496
# 5349194934969
# 3491949349698
# 4919493496983
# 9194934969835
# 1949349698352
# 9493496983520
# 4934969835203
# 9349698352031
# 3496983520312
# 4969835203127
# 9698352031277
# 6983520312774
# 9835203127745
# 8352031277450
# 3520312774506
# 5203127745063
# 2031277450632
# 0312774506326
# 3127745063262
# 1277450632623
# 2774506326239
# 7745063262395
# ...

# %%
def stringprod(string):
    string=str(string)
    count = 1
    for i in string:
        if count == 1:
            prod=i
            count += 1
        else:
            prod=int(i)*int(prod)
    return prod

# %%
stringprod(12345)
# Out:
# 120

# %%
import numpy as np
mymatrix=np.zeros((987,3))
mymatrix.astype(int)
for i in range(0,987):
    mymatrix[i][0]=i
    mymatrix[i][1]=thoudignum[i:(i+13)]
    mymatrix[i][2]=stringprod(thoudignum[i:(i+13)])
mymatrix = mymatrix.astype(int)

# %%
mymatrix
# Out:
# array([[            0, 7316717653133,       5000940],
#        [            1, 3167176531330,             0],
#        [            2, 1671765313306,             0],
#        ...,
#        [          984, 7530420752963,             0],
#        [          985, 5304207529634,             0],
#        [          986, 3042075296345,             0]])

# %%
import pandas as pd
mydf = pd.DataFrame(mymatrix,columns=['a','b','c'])

# %%
mydf['c'].idxmax()
# Out:
# 197

# %%
mydf['b'][mydf['c'].idxmax()]
# Out:
# 5576689664895

# %%
import numpy as np
mymatrix=np.zeros((996,3))
mymatrix.astype(int)
for i in range(0,996):
    mymatrix[i][0]=i
    mymatrix[i][1]=thoudignum[i:(i+4)]
    mymatrix[i][2]=stringprod(thoudignum[i:(i+4)])
mymatrix = mymatrix.astype(int)
mydf = pd.DataFrame(mymatrix,columns=['a','b','c'])
print(mydf['c'][mydf['c'].idxmax()])
print(mydf['b'][mydf['c'].idxmax()])
# Out:
# 5832
# 9989

# %%
import numpy as np
adjdig=13
mymatrix=np.zeros((1000-adjdig,3))
mymatrix.astype(int)
for i in range(0,1000-adjdig):
    mymatrix[i][0]=i
    mymatrix[i][1]=thoudignum[i:(i+adjdig)]
    mymatrix[i][2]=stringprod(thoudignum[i:(i+adjdig)])
mymatrix = mymatrix.astype(int)
mydf = pd.DataFrame(mymatrix,columns=['a','b','c'])
print(mydf['c'][mydf['c'].idxmax()])
print(mydf['b'][mydf['c'].idxmax()])
# Out:
# 23514624000
# 5576689664895
