# %% [markdown]
# # Problem 11
#
# In the 20×20 grid below, four numbers along a diagonal line have been marked in red.
#
# 08 02 22 97 38 15 00 40 00 75 04 05 07 78 52 12 50 77 91 08
# 49 49 99 40 17 81 18 57 60 87 17 40 98 43 69 48 04 56 62 00
# 81 49 31 73 55 79 14 29 93 71 40 67 53 88 30 03 49 13 36 65
# 52 70 95 23 04 60 11 42 69 24 68 56 01 32 56 71 37 02 36 91
# 22 31 16 71 51 67 63 89 41 92 36 54 22 40 40 28 66 33 13 80
# 24 47 32 60 99 03 45 02 44 75 33 53 78 36 84 20 35 17 12 50
# 32 98 81 28 64 23 67 10 26 38 40 67 59 54 70 66 18 38 64 70
# 67 26 20 68 02 62 12 20 95 63 94 39 63 08 40 91 66 49 94 21
# 24 55 58 05 66 73 99 26 97 17 78 78 96 83 14 88 34 89 63 72
# 21 36 23 09 75 00 76 44 20 45 35 14 00 61 33 97 34 31 33 95
# 78 17 53 28 22 75 31 67 15 94 03 80 04 62 16 14 09 53 56 92
# 16 39 05 42 96 35 31 47 55 58 88 24 00 17 54 24 36 29 85 57
# 86 56 00 48 35 71 89 07 05 44 44 37 44 60 21 58 51 54 17 58
# 19 80 81 68 05 94 47 69 28 73 92 13 86 52 17 77 04 89 55 40
# 04 52 08 83 97 35 99 16 07 97 57 32 16 26 26 79 33 27 98 66
# 88 36 68 87 57 62 20 72 03 46 33 67 46 55 12 32 63 93 53 69
# 04 42 16 73 38 25 39 11 24 94 72 18 08 46 29 32 40 62 76 36
# 20 69 36 41 72 30 23 88 34 62 99 69 82 67 59 85 74 04 36 16
# 20 73 35 29 78 31 90 01 74 31 49 71 48 86 81 16 23 57 05 54
# 01 70 54 71 83 51 54 69 16 92 33 48 61 43 52 01 89 19 67 48
#
# The product of these numbers is 26 × 63 × 78 × 14 = 1788696.
#
# What is the greatest product of four adjacent numbers in the same direction (up, down, left, right, or diagonally) in the 20×20 grid?

# %%
import sys 
import os
sys.path.append(os.path.abspath("/home/weberam2/Desktop/ProjectEuler/"))
from projeul import *
primelist(10)
# Out:
# [2, 3, 5, 7]

# %%
grid = [[8, 2, 22, 97, 38, 15, 0, 40, 0, 75, 4, 5, 7, 78, 52, 12, 50, 77, 91, 8],
[49, 49, 99, 40, 17, 81, 18, 57, 60, 87, 17, 40, 98, 43, 69, 48, 4, 56, 62, 0],
[81, 49, 31, 73, 55, 79, 14, 29, 93, 71, 40, 67, 53, 88, 30, 3, 49, 13, 36, 65],
[52, 70, 95, 23, 4, 60, 11, 42, 69, 24, 68, 56, 1, 32, 56, 71, 37, 2, 36, 91],
[22, 31, 16, 71, 51, 67, 63, 89, 41, 92, 36, 54, 22, 40, 40, 28, 66, 33, 13, 80],
[24, 47, 32, 60, 99, 3, 45, 2, 44, 75, 33, 53, 78, 36, 84, 20, 35, 17, 12, 50],
[32, 98, 81, 28, 64, 23, 67, 10, 26, 38, 40, 67, 59, 54, 70, 66, 18, 38, 64, 70],
[67, 26, 20, 68, 2, 62, 12, 20, 95, 63, 94, 39, 63, 8, 40, 91, 66, 49, 94, 21],
[24, 55, 58, 5, 66, 73, 99, 26, 97, 17, 78, 78, 96, 83, 14, 88, 34, 89, 63, 72],
[21, 36, 23, 9, 75, 0, 76, 44, 20, 45, 35, 14, 0, 61, 33, 97, 34, 31, 33, 95],
[78, 17, 53, 28, 22, 75, 31, 67, 15, 94, 3, 80, 4, 62, 16, 14, 9, 53, 56, 92],
[16, 39, 5, 42, 96, 35, 31, 47, 55, 58, 88, 24, 0, 17, 54, 24, 36, 29, 85, 57],
[86, 56, 0, 48, 35, 71, 89, 7, 5, 44, 44, 37, 44, 60, 21, 58, 51, 54, 17, 58],
[19, 80, 81, 68, 5, 94, 47, 69, 28, 73, 92, 13, 86, 52, 17, 77, 4, 89, 55, 40],
[4, 52, 8, 83, 97, 35, 99, 16, 7, 97, 57, 32, 16, 26, 26, 79, 33, 27, 98, 66],
[88, 36, 68, 87, 57, 62, 20, 72, 3, 46, 33, 67, 46, 55, 12, 32, 63, 93, 53, 69],
[4, 42, 16, 73, 38, 25, 39, 11, 24, 94, 72, 18, 8, 46, 29, 32, 40, 62, 76, 36],
[20, 69, 36, 41, 72, 30, 23, 88, 34, 62, 99, 69, 82, 67, 59, 85, 74, 4, 36, 16],
[20, 73, 35, 29, 78, 31, 90, 1, 74, 31, 49, 71, 48, 86, 81, 16, 23, 57, 5, 54],
[1, 70, 54, 71, 83, 51, 54, 69, 16, 92, 33, 48, 61, 43, 52, 1, 89, 19, 67, 48]]

# %%
grid[-1][-1]
# Out:
# 48

# %%
import numpy as np

array = np.array(grid)

rows, columns = array.shape

# %%
columns
# Out:
# 20

# %%
i = 0
array[:4][i]
# Out:
# array([ 8,  2, 22, 97, 38, 15,  0, 40,  0, 75,  4,  5,  7, 78, 52, 12, 50,
#        77, 91,  8])

# %%
import pandas as pd

mydf = pd.DataFrame(grid)

# %%
#Across
list(mydf.iloc[0,i:i+4])
# Out:
# [8, 2, 22, 97]

# %%
#Down
list(mydf.iloc[i:i+4,0])
# Out:
# [8, 49, 81, 52]

# %%
#Diag Neg Slope
lst=[]
for i in range(0,4):
    lst.append(mydf.iloc[i,i])
print(lst)
# Out:
# [8, 49, 31, 23]

# %%
#Diag Pos Slope
lst = []
for i in range(3,-1,-1):
    lst.append(mydf.iloc[i,3-i])
print(lst)
# Out:
# [52, 49, 99, 97]

# %%
from functools import reduce
print(lst)
reduce(lambda x, y: x * y, lst, 1)
# Out:
# [52, 49, 99, 97]
# 24468444

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: [A, B]
# Index: []

# %%
df = pd.DataFrame(columns=['A', 'B'])
cnt = 0
for a in range(0,20):
    for b in range(0,17):
        lst = list(mydf.iloc[a,b:b+4])
        prdt = reduce(lambda x, y: x * y, lst, 1)
        df = df.append({'A': lst}, ignore_index=True)
        df.at[cnt, 'B'] = prdt
        cnt += 1

# %%
df
# Out:
#                     A        B
# 0      [8, 2, 22, 97]    34144
# 1     [2, 22, 97, 38]   162184
# 2    [22, 97, 38, 15]  1216380
# 3     [97, 38, 15, 0]        0
# 4     [38, 15, 0, 40]        0
# ..                ...      ...
# 335   [61, 43, 52, 1]   136396
# 336   [43, 52, 1, 89]   199004
# 337   [52, 1, 89, 19]    87932
# 338   [1, 89, 19, 67]   113297
# 339  [89, 19, 67, 48]  5438256
#
# [340 rows x 2 columns]

# %%
df['B'] = pd.to_numeric(df['B'])
df.loc[df['B'].idxmax()]
# Out:
# A    [78, 78, 96, 83]
# B            48477312
# Name: 146, dtype: object

# %%
df = pd.DataFrame(columns=['A', 'B'])
cnt = 0
for a in range(0,20):
    for b in range(0,17):
        lst = list(mydf.iloc[b:b+4,a])
        prdt = reduce(lambda x, y: x * y, lst, 1)
        df = df.append({'A': lst}, ignore_index=True)
        df.at[cnt, 'B'] = prdt
        cnt += 1

# %%
df
# Out:
#                     A         B
# 0     [8, 49, 81, 52]   1651104
# 1    [49, 81, 52, 22]   4540536
# 2    [81, 52, 22, 24]   2223936
# 3    [52, 22, 24, 32]    878592
# 4    [22, 24, 32, 67]   1132032
# ..                ...       ...
# 335  [58, 40, 66, 69]  10565280
# 336  [40, 66, 69, 36]   6557760
# 337  [66, 69, 36, 16]   2623104
# 338  [69, 36, 16, 54]   2146176
# 339  [36, 16, 54, 48]   1492992
#
# [340 rows x 2 columns]

# %%
df['B'] = pd.to_numeric(df['B'])
df.loc[df['B'].idxmax()]
# Out:
# A    [66, 91, 88, 97]
# B            51267216
# Name: 261, dtype: object

# %%
df = pd.DataFrame(columns=['A', 'B'])
cnt = 0
for a in range(0,20):
    for b in range(0,17):
        lst = list(mydf.iloc[a,b:b+4])
        prdt = reduce(lambda x, y: x * y, lst, 1)
        df = df.append({'A': lst}, ignore_index=True)
        df.at[cnt, 'B'] = prdt
        cnt += 1
for a in range(0,20):
    for b in range(0,17):
        lst = list(mydf.iloc[b:b+4,a])
        prdt = reduce(lambda x, y: x * y, lst, 1)
        df = df.append({'A': lst}, ignore_index=True)
        df.at[cnt, 'B'] = prdt
        cnt += 1
    
df['B'] = pd.to_numeric(df['B'])
df.loc[df['B'].idxmax()]
# Out:
# A    [66, 91, 88, 97]
# B            51267216
# Name: 601, dtype: object

# %%
df
# Out:
#                     A         B
# 0      [8, 2, 22, 97]     34144
# 1     [2, 22, 97, 38]    162184
# 2    [22, 97, 38, 15]   1216380
# 3     [97, 38, 15, 0]         0
# 4     [38, 15, 0, 40]         0
# ..                ...       ...
# 675  [58, 40, 66, 69]  10565280
# 676  [40, 66, 69, 36]   6557760
# 677  [66, 69, 36, 16]   2623104
# 678  [69, 36, 16, 54]   2146176
# 679  [36, 16, 54, 48]   1492992
#
# [680 rows x 2 columns]

# %%
#Diag Neg Slope
lst=[]
for x in range(0,17):
    for y in range(0,17):
        for i in range(0,4):
            lst.append(mydf.iloc[y+i,x+i])
print(lst)
# Out:
# [8, 49, 31, 23, 49, 49, 95, 71, 81, 70, 16, 60, 52, 31, 32, 28, 22, 47, 81, 68, 24, 98, 20, 5, 32, 26, 58, 9, 67, 55, 23, 28, 24, 36, 53, 42, 21, 17, 5, 48, 78, 39, 0, 68, 16, 56, 81, 83, 86, 80, 8, 87, 19, 52, 68, 73, 4, 36, 16, 41, 88, 42, 36, 29, 4, 69, 35, 71, 2, 99, 73, 4, 49, 31, 23, 51, 49, 95, 71, 99, 70, 16, 60, 64, 31, 32, 28, 2, 47, 81, 68, 66, 98, 20, 5, 75, 26, 58, 9, 22, 55, 23, 28, 96, 36, 53, 42, 35, 17, 5, 48, 5, 39, 0, 68, 97, 56, 81, 83, 57, 80, 8, 87, 38, 52, 68, 73, 72, 36, 16, 41, 78, 42, 36, 29, 83, 22, 40, 55, 60, 99, 73, 4, 67, 31, 23, 51, 3, 95, 71, 99, 23, 16, 60, 64, 62, 32, 28, 2, 73, 81, 68, 66, 0, 20, 5, 75, 75, 58, 9, 22, 35, 23, 28, 96, 71, 53, 42, 35, 94, 5, 48, 5, 35, 0, 68, 97, 62, 81, 83, 57, 25, 8, 87, 38, 30, 68, 73, 72, 31, 16, 41, 78, 51, 97, 17, 79, 11, 40, 55, 60, 63, 73, 4, 67, 45, 23, 51, 3, 67, 71, 99, 23, 12, 60, 64, 62, 99, 28, 2, 73, 76, 68, 66, 0, 31, 5, 75, 75, 31, 9, 22, 35, 89, 28, 96, 71, 47, 42, 35, 94, 99, 48, 5, 35, 20, 68, 97,
# ...

# %%
df = pd.DataFrame(columns=['A', 'B'])
cnt = 0
for a in range(0,20):
    for b in range(0,17):
        lst = list(mydf.iloc[a,b:b+4])
        prdt = reduce(lambda x, y: x * y, lst, 1)
        df = df.append({'A': lst}, ignore_index=True)
        df.at[cnt, 'B'] = prdt
        cnt += 1
for a in range(0,20):
    for b in range(0,17):
        lst = list(mydf.iloc[b:b+4,a])
        prdt = reduce(lambda x, y: x * y, lst, 1)
        df = df.append({'A': lst}, ignore_index=True)
        df.at[cnt, 'B'] = prdt
        cnt += 1
for a in range(0,17):
    for b in range(0,17):
        lst = []
        for i in range(0,4):
            lst.append(mydf.iloc[b+i,a+i])
            #print(lst)
            #lst = list(mydf.iloc[lsta])
        prdt = reduce(lambda x, y: x * y, lst, 1)
        df = df.append({'A': lst}, ignore_index=True)
        df.at[cnt, 'B'] = prdt
        cnt += 1
            
df['B'] = pd.to_numeric(df['B'])
df.loc[df['B'].idxmax()]
# Out:
# A    [66, 91, 88, 97]
# B            51267216
# Name: 601, dtype: object

# %%
#Diag Pos Slope
lst=[]
for x in range(0,17):
    for y in range(0,17):
        for i in range(3,-1,-1):
            lst.append(mydf.iloc[y+i,3-i+x])
print(lst)
# Out:
# [52, 49, 99, 97, 22, 70, 31, 40, 24, 31, 95, 73, 32, 47, 16, 23, 67, 98, 32, 71, 24, 26, 81, 60, 21, 55, 20, 28, 78, 36, 58, 68, 16, 17, 23, 5, 86, 39, 53, 9, 19, 56, 5, 28, 4, 80, 0, 42, 88, 52, 81, 48, 4, 36, 8, 68, 20, 42, 68, 83, 20, 69, 16, 87, 1, 73, 36, 73, 70, 31, 40, 38, 31, 95, 73, 17, 47, 16, 23, 55, 98, 32, 71, 4, 26, 81, 60, 51, 55, 20, 28, 99, 36, 58, 68, 64, 17, 23, 5, 2, 39, 53, 9, 66, 56, 5, 28, 75, 80, 0, 42, 22, 52, 81, 48, 96, 36, 8, 68, 35, 42, 68, 83, 5, 69, 16, 87, 97, 73, 36, 73, 57, 70, 35, 41, 38, 95, 73, 17, 15, 16, 23, 55, 81, 32, 71, 4, 79, 81, 60, 51, 60, 20, 28, 99, 67, 58, 68, 64, 3, 23, 5, 2, 23, 53, 9, 66, 62, 5, 28, 75, 73, 0, 42, 22, 0, 81, 48, 96, 75, 8, 68, 35, 35, 68, 83, 5, 71, 16, 87, 97, 94, 36, 73, 57, 35, 35, 41, 38, 62, 54, 29, 72, 25, 23, 55, 81, 0, 71, 4, 79, 18, 60, 51, 60, 14, 28, 99, 67, 11, 68, 64, 3, 63, 5, 2, 23, 45, 9, 66, 62, 67, 28, 75, 73, 12, 42, 22, 0, 99, 48, 96, 75, 76, 68, 35, 35, 31, 83, 5, 71, 31, 87, 97, 94, 89, 73, 57,
# ...

# %%
df = pd.DataFrame(columns=['A', 'B'])
cnt = 0
for a in range(0,20):
    for b in range(0,17):
        lst = list(mydf.iloc[a,b:b+4])
        prdt = reduce(lambda x, y: x * y, lst, 1)
        df = df.append({'A': lst}, ignore_index=True)
        df.at[cnt, 'B'] = prdt
        cnt += 1
for a in range(0,20):
    for b in range(0,17):
        lst = list(mydf.iloc[b:b+4,a])
        prdt = reduce(lambda x, y: x * y, lst, 1)
        df = df.append({'A': lst}, ignore_index=True)
        df.at[cnt, 'B'] = prdt
        cnt += 1
for a in range(0,17):
    for b in range(0,17):
        lst = []
        for i in range(0,4):
            lst.append(mydf.iloc[b+i,a+i])
        prdt = reduce(lambda x, y: x * y, lst, 1)
        df = df.append({'A': lst}, ignore_index=True)
        df.at[cnt, 'B'] = prdt
        cnt += 1
for a in range(0,17):
    for b in range(0,17):
        lst = []
        for i in range(3,-1,-1):
            lst.append(mydf.iloc[b+i,3-i+a])
        prdt = reduce(lambda x, y: x * y, lst, 1)
        df = df.append({'A': lst}, ignore_index=True)
        df.at[cnt, 'B'] = prdt
        cnt += 1
df['B'] = pd.to_numeric(df['B'])
df.loc[df['B'].idxmax()]
# Out:
# A    [87, 97, 94, 89]
# B            70600674
# Name: 1032, dtype: object
